# %% [markdown]
# # Kuragayala Kenny Joel ML LAB - 2

# %% [markdown]
# # Lab -2 assignment for ML (24-02-2023)
#
#
# #Task 1 Data Cleansing - Data Imputation/ Wrangling, Statistical analysis, Data distributions, Outlier Detection for minimum 3 different datasets form kaggle.
#
# #Task 2 Applying different data splitting techniques for model preperation for minimum 2 different datasets form kaggle and 1 dataset sythetic data genaration with 1000. You may use make_Classification in sklearn
#
# #Task 3 Applying the data splitting and then apply latest library lazy predict
#
#
#
#
# **A detailed report with your observations and comments is mandatory as required.**
#
# #Instructions for report in same jupyter notebook:
#
# #Task 1: A detailed report should include what data cleansing techniques you have used, winsorization/ scatterplot/ box plot/ pairplot for outlier detection, data train/test split criteria
#
#
# #Task 2: Also, include the synthetic data generation how you are doing, and what datssets you consider, what tasks you are performing. Expecially for synthetic data, work on detailed analysis for imbalanaced and balanced dataset
#
#
# #Task 3: Apply data preprcoessing, distributions plots, correlation analysis, feature importance, removing outliers, noise data, apply all 4 different data splitting techniques used for model preperation, then apply lazy predict. Observe and list all the hyper=parameters essential for improved model's generalization capability.
#
#
# #Deadline: 27th Jan 2023 - by 6pm. No copying. Enjoy practical learning
#
#
# **References:**
#
# #https://www.kaggle.com/datasets/
# #https://archive.ics.uci.edu/ml/datasets.php
# #https://datasetsearch.research.google.com/
# #https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
# #https://scikit-learn.org/stable/datasets.html#:~:text=The%20sklearn.datasets%20package%20embeds%20some%20small%20toy%20datasets,on%20data%20that%20comes%20from%20the%20%E2%80%98real%20world%E2%80%99.

# %% [markdown]
# # TASK 1

# %% [markdown]
# **Importing Numpy and Pandas Library**
#
# Here I am inporting Numpy and Pandas library for Data preprocessing and Data visualization
#
# Data Cleansing - Data Imputation/ Wrangling, Statistical analysis, Data distributions, Outlier Detection

# %%
#Importing Numpy and Pandas Library
import numpy as np
import pandas as pd

# %% [markdown]
# **Importing the GHI dataset**
#
# We are inporting the GHI dataset and loading the dataset with the specific sheet name 2022 GHI Indicator Values

# %%
#Importing the GHI dataset
df = pd.read_excel('C:/Users/pc/Desktop/2022.xlsx', sheet_name = "2022 GHI Indicator values")

# %% [markdown]
# **Trying to load dataset**
#
# We are loading dataset which we defined our dataset with 'df'

# %%
#Loading Dataset
df
# Out:
#      Unnamed: 0                                            Country 2000–2002  \
# 0           NaN                                                NaN       NaN
# 1           NaN                                        Afghanistan     47.80
# 2           NaN                                            Albania      4.90
# 3           NaN                                            Algeria         8
# 4           NaN                                             Angola     67.50
# ..          ...                                                ...       ...
# 134         NaN                                              Yemen     26.70
# 135         NaN                                             Zambia     51.70
# 136         NaN                                           Zimbabwe       NaN
# 137         NaN                                                NaN       NaN
# 138         NaN  — = Data not available or not presented. Some ...       NaN
#
# ...

# %% [markdown]
# **Dropping Unwanted Columns in Dataset**
#
# We are droping columns 'Unnamed: 0','Unnamed: 7','Unnamed: 9','Unnamed: 11','Unnamed: 13','Unnamed: 15','Unnamed: 17','Unnamed: 19','Unnamed: 21' which we don't require.
#
# We are using drop column function

# %%
#Dropping Columns
df = df.drop(columns=['Unnamed: 0','Unnamed: 7','Unnamed: 9','Unnamed: 11','Unnamed: 13','Unnamed: 15','Unnamed: 17','Unnamed: 19','Unnamed: 21'])

# %% [markdown]
# Here you can see the unwanted Datasets has been deleted

# %%
#Displaying Updated Dataset
df
# Out:
#                                                Country 2000–2002 2006–2008  \
# 0                                                  NaN       NaN       NaN
# 1                                          Afghanistan     47.80     29.80
# 2                                              Albania      4.90      8.30
# 3                                              Algeria         8      5.90
# 4                                               Angola     67.50     46.10
# ..                                                 ...       ...       ...
# 134                                              Yemen     26.70     26.10
# 135                                             Zambia     51.70     55.50
# 136                                           Zimbabwe       NaN       NaN
# 137                                                NaN       NaN       NaN
# 138  — = Data not available or not presented. Some ...       NaN       NaN
#
# ...

# %% [markdown]
# **Dropping Unwanted Rows in the Dataset**
#
# Here you can see we are dropping the unwanted rows in dataset using drop function

# %%
#Dropping Rows
df = df.drop([0,137,138])

# %% [markdown]
# Here we are displaying updated dataset

# %%
#Displaying
df
# Out:
#                         Country 2000–2002 2006–2008 2013–2015 2019–2021  \
# 1                   Afghanistan     47.80     29.80     20.70     29.80
# 2                       Albania      4.90      8.30         5      3.90
# 3                       Algeria         8      5.90      2.90      <2.5
# 4                        Angola     67.50     46.10     13.70     20.80
# 5                     Argentina         3      3.30      <2.5      3.70
# ..                          ...       ...       ...       ...       ...
# 132  Venezuela (Boliv. Rep. of)     14.90      4.80      4.50     22.90
# 133                    Viet Nam     19.70     14.10      8.60      5.70
# 134                       Yemen     26.70     26.10     38.10     41.40
# 135                      Zambia     51.70     55.50     37.70     30.90
# 136                    Zimbabwe       NaN       NaN       NaN       NaN
#
#      1998–2002  2005–2009  2012–2016  2017–2021  1998–2002.1  2005–2009.1  \
# ...

# %% [markdown]
# **Statistical Analysis**
#
# Here we are seeing the statistical analysis of the dataset with describe function
#
# Only describe funtion will give statistical analysis of the columns which have integer
#
# But if you use include = all this will give of every column
#
# But we can so many missing values now we should fill the values with mean

# %%
#Statistical Analysis
df.describe(include='all')
# Out:
#             Country 2000–2002 2006–2008 2013–2015 2019–2021  1998–2002  \
# count           136       121       121       121       121     132.00
# unique          136       101        94        87        85        NaN
# top     Afghanistan      <2.5      <2.5      <2.5      <2.5        NaN
# freq              1         5        15        19        18        NaN
# mean            NaN       NaN       NaN       NaN       NaN       7.41
# std             NaN       NaN       NaN       NaN       NaN       4.75
# min             NaN       NaN       NaN       NaN       NaN       0.50
# 25%             NaN       NaN       NaN       NaN       NaN       3.08
# 50%             NaN       NaN       NaN       NaN       NaN       6.95
# 75%             NaN       NaN       NaN       NaN       NaN      10.47
# max             NaN       NaN       NaN       NaN       NaN      19.40
#
#         2005–2009  2012–2016  2017–2021  1998–2002.1  2005–2009.1  \
# ...

# %% [markdown]
# Now we are we seeing 1st 5 rows of the dataset

# %%
#Displaying first 5 rows
df.head()
# Out:
#        Country 2000–2002 2006–2008 2013–2015 2019–2021  1998–2002  2005–2009  \
# 1  Afghanistan     47.80     29.80     20.70     29.80      10.90       8.30
# 2      Albania      4.90      8.30         5      3.90      12.20       8.50
# 3      Algeria         8      5.90      2.90      <2.5       3.10       4.10
# 4       Angola     67.50     46.10     13.70     20.80      11.20       8.20
# 5    Argentina         3      3.30      <2.5      3.70       1.70       1.20
#
#    2012–2016  2017–2021  1998–2002.1  2005–2009.1  2012–2016.1  2017–2021.1  \
# 1       9.50       5.10        50.60        51.10        40.40        38.20
# 2       4.50       1.60        39.20        25.00        15.20        11.30
# 3       4.10       2.70        23.60        15.40        11.70         9.80
# 4       4.90       6.10        46.70        29.20        37.60        29.80
# 5       1.60       2.70        10.50         8.20         8.30        12.30
#
#    2000  2007  2014  2020
# ...

# %% [markdown]
# **Getting output of missing values**
#
# Now we are getting output of missing values of each coloumn like how many missing values does the column contain

# %%
# Seeing how many missing values
GHI_NULL = df.isna().sum()
print(GHI_NULL)
# Out:
# Country         0
# 2000–2002      15
# 2006–2008      15
# 2013–2015      15
# 2019–2021      15
# 1998–2002       4
# 2005–2009       3
# 2012–2016       4
# 2017–2021       4
# 1998–2002.1     4
# 2005–2009.1     3
# 2012–2016.1     4
# 2017–2021.1     4
# 2000            0
# 2007            0
# 2014            0
# 2020            0
# dtype: int64

# %% [markdown]
# **Filling with mean values**
#
# Now we are filling missing values with the mean with respect to column

# %%
#Filling with mean values
Mean_Undernourished = df['2000–2002'].mean()
df['2000–2002'].fillna(Mean_Undernourished, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4416/510069527.py in <module>
# ----> 1 Mean_Undernourished = df['2000–2002'].mean()
#       2 df['2000–2002'].fillna(Mean_Undernourished, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
# ...

# %% [markdown]
# **Replacing <2.5 with 2.5**
#
# As we can see we have encountered an error.
#
# This is because we contain <2.5 which cannot be convert to float to take mean.
#
# So we are replacing <2.5 with 2.5
#
# We are replacing with replace function

# %%
#Replacing <2.5 with 2.5
df = df.replace('<2.5', 2.5)

# %% [markdown]
# Now again we are applying the mean and filling the missing attributes

# %%
#Filling with mean values
Mean_Undernourished = df['2000–2002'].mean()
df['2000–2002'].fillna(Mean_Undernourished, inplace=True)

# %% [markdown]
# Here we are displaying updated dataset

# %%
#Displaying
df
# Out:
#                         Country  2000–2002  2006–2008  2013–2015  2019–2021  \
# 1                   Afghanistan      47.80      29.80      20.70      29.80
# 2                       Albania       4.90       8.30       5.00       3.90
# 3                       Algeria       8.00       5.90       2.90       2.50
# 4                        Angola      67.50      46.10      13.70      20.80
# 5                     Argentina       3.00       3.30       2.50       3.70
# ..                          ...        ...        ...        ...        ...
# 132  Venezuela (Boliv. Rep. of)      14.90       4.80       4.50      22.90
# 133                    Viet Nam      19.70      14.10       8.60       5.70
# 134                       Yemen      26.70      26.10      38.10      41.40
# 135                      Zambia      51.70      55.50      37.70      30.90
# 136                    Zimbabwe      17.84        NaN        NaN        NaN
#
# ...

# %% [markdown]
# **Missing Values filled**
#
# Now we can see the 2000-2002 column has no missing values but earlier it has 14 missing values now filled with respective column mean.

# %%
#Displaying Missing Values
GHI_NULL = df.isna().sum()
print(GHI_NULL)
# Out:
# Country         0
# 2000–2002       0
# 2006–2008      15
# 2013–2015      15
# 2019–2021      15
# 1998–2002       4
# 2005–2009       3
# 2012–2016       4
# 2017–2021       4
# 1998–2002.1     4
# 2005–2009.1     3
# 2012–2016.1     4
# 2017–2021.1     4
# 2000            0
# 2007            0
# 2014            0
# 2020            0
# dtype: int64

# %% [markdown]
# **Filling Missing values with respective to column**
#
# Now we are filling the missing of each attribute with respective to thier column

# %%
#Filling the missing values with '2006–2008' column mean
Mean_1 = df['2006–2008'].mean()
df['2006–2008'].fillna(Mean_1, inplace=True)

#Filling the missing values with '2013–2015' column mean
Mean_2 = df['2013–2015'].mean()
df['2013–2015'].fillna(Mean_2, inplace=True)

#Filling the missing values with '2019–2021' column mean
Mean_3= df['2019–2021'].mean()
df['2019–2021'].fillna(Mean_3, inplace=True)

#Filling the missing values with '1998–2002' column mean
Mean_4= df['1998–2002'].mean()
df['1998–2002'].fillna(Mean_4, inplace=True)

#Filling the missing values with '2005–2009' column mean
Mean_5= df['2005–2009'].mean()
df['2005–2009'].fillna(Mean_5, inplace=True)

#Filling the missing values with '2012–2016' column mean
Mean_6= df['2012–2016'].mean()
df['2012–2016'].fillna(Mean_6, inplace=True)

#Filling the missing values with '2017–2021' column mean
Mean_7= df['2017–2021'].mean()
df['2017–2021'].fillna(Mean_7, inplace=True)

#Filling the missing values with '1998–2002.1' column mean
Mean_7= df['1998–2002.1'].mean()
df['1998–2002.1'].fillna(Mean_8, inplace=True)

#Filling the missing values with '2005–2009.1' column mean
Mean_9= df['2005–2009.1'].mean()
df['2005–2009.1'].fillna(Mean_9, inplace=True)

#Filling the missing values with '2012–2016.1' column mean
Mean_10= df['2012–2016.1'].mean()
df['2012–2016.1'].fillna(Mean_10, inplace=True)

#Filling the missing values with '2017–2021.1' column mean
Mean_11= df['2017–2021.1'].mean()
df['2017–2021.1'].fillna(Mean_11, inplace=True)

# %% [markdown]
# **Displaying the updated Dataset**
#
# Now we are displaying the dataset which has been filled missing values with their column mean

# %%
#Displaying the updated Dataset
df
# Out:
#                         Country  2000–2002  2006–2008  2013–2015  2019–2021  \
# 1                   Afghanistan      47.80      29.80      20.70      29.80
# 2                       Albania       4.90       8.30       5.00       3.90
# 3                       Algeria       8.00       5.90       2.90       2.50
# 4                        Angola      67.50      46.10      13.70      20.80
# 5                     Argentina       3.00       3.30       2.50       3.70
# ..                          ...        ...        ...        ...        ...
# 132  Venezuela (Boliv. Rep. of)      14.90       4.80       4.50      22.90
# 133                    Viet Nam      19.70      14.10       8.60       5.70
# 134                       Yemen      26.70      26.10      38.10      41.40
# 135                      Zambia      51.70      55.50      37.70      30.90
# 136                    Zimbabwe      17.84      14.67      11.55      12.50
#
# ...

# %% [markdown]
# **Missing Values filled**
#
# Now we can see the All columns has no missing values but earlier it has missing values now filled with respective column mean.

# %%
#Displaying Missing Values
GHI_NULL = df.isna().sum()
print(GHI_NULL)
# Out:
# Country        0
# 2000–2002      0
# 2006–2008      0
# 2013–2015      0
# 2019–2021      0
# 1998–2002      0
# 2005–2009      0
# 2012–2016      0
# 2017–2021      0
# 1998–2002.1    0
# 2005–2009.1    0
# 2012–2016.1    0
# 2017–2021.1    0
# 2000           0
# 2007           0
# 2014           0
# 2020           0
# dtype: int64

# %% [markdown]
# **Importing matplotlib and seaborn libraries**
#
# Now we are importing matplotlib and seaborn libraries to do data visualization and data distribution in order to find outliers in the dataset

# %%
#Importing matplotlib library
import matplotlib.pyplot as plt

# %%
#Importing seaborn library
import seaborn as sns

# %% [markdown]
# **Correlation Analysis**
#
# Now we are doing correlation analysis.
#
# And to get the analysis we are using heat map with the help of the seaborn library

# %%
#Correlation
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# **Outlier Detection**
#
# We are using boxplpt to detect the outliers in the dataset.
#
# Boxplot gives the coreect outliers with respective of every column

# %%
#used seaborn to get boxplot
sns.boxplot(data=df, x='2000–2002')
plt.show()

# %% [markdown]
# **Outliers**
#
# Now we are seeing boxplot of every collumn to check the outliers in each column in the dataset

# %%
#Boxplot for outliers for the column '2000–2002'
df.boxplot(column=['2000–2002'])
plt.show()

# %%
#Boxplot for outliers for the column '2006–2008'
df.boxplot(column=['2006–2008'])
plt.show()

# %%
#Boxplot for outliers for the column '2013–2015'
df.boxplot(column=['2013–2015'])
plt.show()

# %%
#Boxplot for outliers for the column '2019–2021'
df.boxplot(column=['2019–2021'])
plt.show()

# %%
#Boxplot for outliers for the column '1998–2002'
df.boxplot(column=['1998–2002'])
plt.show()

# %%
#Boxplot for outliers for the column '2005–2009'
df.boxplot(column=['2005–2009'])
plt.show()

# %%
#Boxplot for outliers for the column '2012–2016'
df.boxplot(column=['2012–2016'])
plt.show()

# %%
#Boxplot for outliers for the column '2017–2021'
df.boxplot(column=['2017–2021'])
plt.show()

# %%
#Boxplot for outliers for the column '1998–2002.1'
df.boxplot(column=['1998–2002.1'])
plt.show()

# %%
#Boxplot for outliers for the column '2005–2009.1'
df.boxplot(column=['2005–2009.1'])
plt.show()

# %%
#Boxplot for outliers for the column '2012–2016.1'
df.boxplot(column=['2012–2016.1'])
plt.show()

# %%
#Boxplot for outliers for the column '2017–2021.1'
df.boxplot(column=['2017–2021.1'])
plt.show()

# %%
#Boxplot for outliers for the column '2000'
df.boxplot(column=[2000])
plt.show()

# %%
#Boxplot for outliers for the column '2007'
df.boxplot(column=[2007])
plt.show()

# %%
#Boxplot for outliers for the column '2014'
df.boxplot(column=[2014])
plt.show()

# %%
#Boxplot for outliers for the column '2020'
df.boxplot(column=[2020])
plt.show()

# %% [markdown]
# **Pairplot**
#
# Now we are using pairplot from seaborn library which give scatterplot of every column
#
# We can know the outliers easily

# %%
#Pairplot using seaborn library
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Task 2

# %% [markdown]
# **Splitting train and test dataset**
#
# Now we are splitting the dataset of specfic columns 'Country', '2000–2002', '2006–2008', '2013–2015','2019–2021'
#
# Now we are taking
#
# X = 'Country', '2000–2002', '2006–2008', '2013–2015'
#
# Y = '2019–2021'
#
# Now we are taking test as 20% and train 80% and random state as 42 which is optimal

# %%
#importing make_classifier in sklearn
from sklearn.model_selection import train_test_split

# Spliting the data into (X) and labels (y)
X = df[['Country', '2000–2002', '2006–2008', '2013–2015']]
Y = df['2019–2021']

# Spliting the data into training and testing 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
#Displaying X_train
X_train
# Out:
#                 Country  2000–2002  2006–2008  2013–2015
# 12               Bhutan      17.84      14.67      11.55
# 69              Lebanon       7.80       9.90       5.50
# 130             Uruguay       3.60       3.10       2.50
# 77             Maldives      17.84      14.67      11.55
# 85              Morocco       6.30       5.50       4.10
# ..                  ...        ...        ...        ...
# 72                Libya      17.84      14.67      11.55
# 107              Serbia       3.10       2.50       3.70
# 15             Botswana      23.70      22.20      19.30
# 93      North Macedonia       7.50       3.60       3.50
# 103  Russian Federation       4.00       2.50       2.50
#
# [108 rows x 4 columns]

# %%
#Displaying X_test
X_test
# Out:
#                           Country  2000–2002  2006–2008  2013–2015
# 74                     Madagascar      33.80      30.50      37.60
# 46                         Gambia      17.80      18.70      10.50
# 61                         Jordan       9.70       6.10       6.00
# 43                       Ethiopia      47.00      35.00      15.90
# 129          United Arab Emirates       2.80       8.10       6.60
# 63                          Kenya      32.20      26.90      19.60
# 13   Bolivia (Plurinat. State of)      27.90      23.90      15.60
# 82              Moldova (Rep. of)      24.60      30.70       6.40
# 20                     Cabo Verde      14.50      12.30      16.20
# 65                         Kuwait       2.60       2.50       2.50
# 45                          Gabon      10.70      15.90      13.30
# 52                         Guyana       6.50       7.50       7.00
# 27                       Colombia       8.70      11.00       7.50
# ...

# %%
#Displaying Y_train
Y_train
# Out:
# 12    12.50
# 69    10.90
# 130    2.50
# 77    12.50
# 85     5.60
#        ...
# 72    12.50
# 107    3.30
# 15    21.90
# 93     3.30
# 103    2.50
# Name: 2019–2021, Length: 108, dtype: float64

# %%
#Displaying Y_test
Y_test
# Out:
# 74    48.50
# 46    21.60
# 61    16.90
# 43    24.90
# 129    5.60
# 63    26.90
# 13    13.90
# 82     6.70
# 20    17.70
# 65     2.70
# 45    17.20
# 52     4.90
# 27     8.20
# 37     5.10
# 32     2.50
# 41     2.50
# 133    5.70
# 106    7.50
# 5      3.70
# 113   12.50
# 121   26.20
# 127   12.50
# 28    20.40
# 17     3.00
# 19    12.50
# 11     7.40
# 67     5.10
# 70    34.70
# Name: 2019–2021, dtype: float64

# %% [markdown]
# Now we are seeing statistiscal analysis train and test datasets

# %%
#Displaying statistiscal analysis
X_train.describe()
# Out:
#        2000–2002  2006–2008  2013–2015
# count     108.00     108.00     108.00
# mean       17.88      14.65      11.56
# std        12.96      11.50      10.04
# min         2.50       2.50       2.50
# 25%         7.35       5.17       4.38
# 50%        17.84      13.15       8.50
# 75%        23.05      18.27      14.22
# max        67.50      55.50      47.90

# %%
#Displaying statistiscal analysis
X_test.describe()
# Out:
#        2000–2002  2006–2008  2013–2015
# count      28.00      28.00      28.00
# mean       17.70      14.76      11.48
# std        12.21       9.60       8.35
# min         2.60       2.50       2.50
# 25%         6.72       7.15       6.30
# 50%        17.82      13.85       9.55
# 75%        25.23      19.73      15.68
# max        47.00      35.00      37.60

# %%
#Displaying statistiscal analysis
Y_train.describe()
# Out:
# count   108.00
# mean     12.25
# std      11.01
# min       2.50
# 25%       3.68
# 50%       8.65
# 75%      16.07
# max      52.20
# Name: 2019–2021, dtype: float64

# %%
#Displaying statistiscal analysis
Y_test.describe()
# Out:
# count   28.00
# mean    13.46
# std     11.15
# min      2.50
# 25%      5.10
# 50%     10.35
# 75%     18.38
# max     48.50
# Name: 2019–2021, dtype: float64

# %% [markdown]
# Using boxplot with seaborn library to see outliers

# %%
#Using seaborn library to see outliers
sns.boxplot(data=X_train)
plt.show()

# %% [markdown]
# **Generating synthetic values**
#
# 1st we are generating synthetic values with the help of make classifier function in sk learn library which can generate synthetic values
#
# Here according to the dataset i have taken
#
# Columns 17
# Rows 1000

# %%
#Importing make_classifier from sklearn
from sklearn.datasets import make_classification

# Set the number of features and samples for the synthetic data
n_features = 17
n_samples = 1000

# Generate the synthetic data
X, y = make_classification(n_features=n_features, n_samples=n_samples)

# %%
# Convert the synthetic data to a pandas DataFrame
df = pd.DataFrame(X, columns=['Country','2000–2002','2006–2008','2013–2015','2019–2021','1998–2002','2005–2009','2012–2016','2017–2021','1998–2002.1','2005–2009.1','2012–2016.1','2017–2021.1','2000','2007','2014','2020'])
df['label'] = y

# Print the first few rows of the DataFrame to verify the data
print(df.head())
# Out:
#    Country  2000–2002  2006–2008  2013–2015  2019–2021  1998–2002  2005–2009  \
# 0     1.24       1.19      -0.52       0.75      -0.75       0.31       1.34
# 1     0.11      -0.55      -0.24       0.13      -2.78      -1.28      -1.00
# 2     1.26      -0.17      -0.17      -0.69       0.20      -1.01      -0.74
# 3    -1.53       0.95      -0.86       2.18      -0.05       2.16       1.91
# 4    -1.47       0.68      -0.97       0.28       0.11      -0.77       1.73
#
#    2012–2016  2017–2021  1998–2002.1  2005–2009.1  2012–2016.1  2017–2021.1  \
# 0       0.46      -0.07        -1.16        -1.50        -0.91        -0.26
# 1      -0.14      -1.96         2.35        -0.24        -0.61        -1.86
# 2      -0.16       0.09         0.01         2.83         1.07         1.28
# 3       1.45       0.04        -0.30        -0.51        -0.91         1.09
# 4      -0.16       1.67         0.27         0.87        -0.30         0.62
#
#    2000  2007  2014  2020  label
# ...

# %% [markdown]
# Displaying the dataset with the synthetic vales we can see 1000 columns

# %%
#Displaying the dataset with the synthetic vales
df
# Out:
#      Country  2000–2002  2006–2008  2013–2015  2019–2021  1998–2002  \
# 0       1.24       1.19      -0.52       0.75      -0.75       0.31
# 1       0.11      -0.55      -0.24       0.13      -2.78      -1.28
# 2       1.26      -0.17      -0.17      -0.69       0.20      -1.01
# 3      -1.53       0.95      -0.86       2.18      -0.05       2.16
# 4      -1.47       0.68      -0.97       0.28       0.11      -0.77
# ..       ...        ...        ...        ...        ...        ...
# 995     1.14      -1.58       0.21       1.28      -1.72      -0.34
# 996    -0.78       1.63      -0.21       2.08      -0.97      -0.66
# 997     0.74       0.03       0.66       1.28      -1.02      -1.45
# 998    -0.55      -0.07       1.04       0.85      -0.01      -1.66
# 999    -1.34      -0.27       0.57      -1.93      -0.12      -0.48
#
#      2005–2009  2012–2016  2017–2021  1998–2002.1  2005–2009.1  2012–2016.1  \
# ...

# %% [markdown]
# # Task 3

# %% [markdown]
# Installing lazypredict library

# %%
#Installing lazypredict library
pip install lazypredict
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing lazy predictict
import lazypredict

# %% [markdown]
# Now we are applying lazypredict for the splitted dataset previous
#
# Setting values with verbose and getting out outputs

# %%
#importing lazyclassifier
from lazypredict.Supervised import LazyClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =42)

#setting values with verbose and getting out outputs
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 22.47it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.96               0.96     0.96      0.96
# LGBMClassifier                     0.95               0.95     0.95      0.95
# XGBClassifier                      0.95               0.95     0.95      0.95
# RandomForestClassifier             0.94               0.94     0.94      0.94
# LogisticRegression                 0.94               0.94     0.94      0.94
# LinearSVC                          0.94               0.94     0.94      0.94
# CalibratedClassifierCV             0.94               0.93     0.93      0.93
# AdaBoostClassifier                 0.94               0.93     0.93      0.93
# LinearDiscriminantAnalysis         0.93               0.93     0.93      0.93
# ...

# %% [markdown]
# Now splittting the dataset with synthetic values

# %%
#importing train_test_split from sklearn.model_selection
from sklearn.model_selection import train_test_split

# Split the data into features (X) and labels (y)
X = df[['Country', '2000–2002', '2006–2008', '2013–2015']]
Y = df['2019–2021']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# Now applying lazypredict here we can see not optimal accuracy because so much noise

# %%
#importing lazyclassifier
from lazypredict.Supervised import LazyClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =42)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 24.42it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.58               0.59     0.59      0.58
# KNeighborsClassifier               0.55               0.55     0.55      0.55
# Perceptron                         0.55               0.55     0.55      0.54
# CalibratedClassifierCV             0.55               0.55     0.55      0.54
# LinearSVC                          0.55               0.55     0.55      0.54
# RidgeClassifierCV                  0.55               0.55     0.55      0.54
# RidgeClassifier                    0.55               0.55     0.55      0.54
# LinearDiscriminantAnalysis         0.55               0.55     0.55      0.54
# LogisticRegression                 0.55               0.55     0.55      0.54
# ...
